# %%
import json
import requests

# %%
#https://github.com/AdityaMohan7

username = 'AdityaMohan7'
url = 'https://api.github.com/users/{}'.format(username)

# %%
url
# Out:
# 'https://api.github.com/users/AdityaMohan7'

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# {"login":"AdityaMohan7","id":113836611,"node_id":"U_kgDOBskCQw","avatar_url":"https://avatars.githubusercontent.com/u/113836611?v=4","gravatar_id":"","url":"https://api.github.com/users/AdityaMohan7","html_url":"https://github.com/AdityaMohan7","followers_url":"https://api.github.com/users/AdityaMohan7/followers","following_url":"https://api.github.com/users/AdityaMohan7/following{/other_user}","gists_url":"https://api.github.com/users/AdityaMohan7/gists{/gist_id}","starred_url":"https://api.github.com/users/AdityaMohan7/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/AdityaMohan7/subscriptions","organizations_url":"https://api.github.com/users/AdityaMohan7/orgs","repos_url":"https://api.github.com/users/AdityaMohan7/repos","events_url":"https://api.github.com/users/AdityaMohan7/events{/privacy}","received_events_url":"https://api.github.com/users/AdityaMohan7/received_events","type":"User","site_admin":false,"name":null,"company":null,"blog":"","location":null,"email":null,"hireable":null,"bio":null,"twitter_username":null,"public_repos":0,"public_gists":0,"followers":0,"following":0,"created_at":"2022-09-18T11:52:17Z","updated_at":"2022-12-31T13:47:00Z"}

# %%
type(response.text)
# Out:
# str

# %%
output = response.json()

# %%
type(output)
# Out:
# dict

# %%
output
# Out:
# {'login': 'AdityaMohan7',
#  'id': 113836611,
#  'node_id': 'U_kgDOBskCQw',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/113836611?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/AdityaMohan7',
#  'html_url': 'https://github.com/AdityaMohan7',
#  'followers_url': 'https://api.github.com/users/AdityaMohan7/followers',
#  'following_url': 'https://api.github.com/users/AdityaMohan7/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/AdityaMohan7/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/AdityaMohan7/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/AdityaMohan7/subscriptions',
#  'organizations_url': 'https://api.github.com/users/AdityaMohan7/orgs',
#  'repos_url': 'https://api.github.com/users/AdityaMohan7/repos',
#  'events_url': 'https://api.github.com/users/AdityaMohan7/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/AdityaMohan7/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': None,
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 0,
#  'public_gists': 0,
#  'followers': 0,
#  'following': 0,
#  'created_at': '2022-09-18T11:52:17Z',
#  'updated_at': '2022-12-31T13:47:00Z'}

# %%
output['avatar_url']
# Out:
# 'https://avatars.githubusercontent.com/u/113836611?v=4'

# %%
response_img = requests.get(output['avatar_url'])

pic = open('{}_img.png'.format(username),'wb')
pic.write(response_img.content)
pic.close()

# %%
from skimage import io

img_url = output['avatar_url']

img = io.imread(img_url)

io.imshow(img)
